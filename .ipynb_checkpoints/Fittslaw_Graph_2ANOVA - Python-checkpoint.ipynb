# %% [markdown]
# #### **Importing Libraries**

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

sns.set(style='whitegrid', font_scale=1.2)

# %% [markdown]
# #### **Loading Data**

# %%
# Loading the data
df = pd.read_csv('anova_test_csv.csv')
df.head()
# Out:
#   participant_code   condition  start_cvs_score  end_cvs_score  \
# 0               P0   No Change                2              4
# 1               P0   Font Size                4              7
# 2               P0  Brightness                1              1
# 3               P1   No Change                1              2
# 4               P1  Brightness                0              1
#
#    difference_cvs_score  backspace_count  ratio_backspace_word_count  \
# 0                     2              177                    0.274845
# 1                     3              209                    0.305556
# 2                     0              196                    0.230860
# 3                     1              150                    0.153374
# 4                     1              173                    0.158280
#
#    word_count  percent_change_word_count
# 0         644                        0.0
# 1         684                        6.2
# 2         849                       24.1
# 3         978                        0.0
# 4        1093                       11.8

# %%
# drop unnecessary columns
df.drop(columns=['start_cvs_score', 'end_cvs_score', 'backspace_count', 'word_count'], inplace=True)
df.head()
# Out:
#   participant_code   condition  difference_cvs_score  \
# 0               P0   No Change                     2
# 1               P0   Font Size                     3
# 2               P0  Brightness                     0
# 3               P1   No Change                     1
# 4               P1  Brightness                     1
#
#    ratio_backspace_word_count  percent_change_word_count
# 0                    0.274845                        0.0
# 1                    0.305556                        6.2
# 2                    0.230860                       24.1
# 3                    0.153374                        0.0
# 4                    0.158280                       11.8

# %% [markdown]
# #### **Visualizing Data**

# %%
# Visualizing the effect of input type on mean completion time and mean click error

# Creating two subfigures
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Mean completion time by input type
sns.barplot(
    ax=axes[0],
    data=df, 
    x='input', 
    y='mean_completion_time', 
    ci='sd', 
    capsize=.05, 
    palette='husl'
)
axes[0].set_xlabel('Input Type')
axes[0].set_ylabel('Mean Completion Time (ms)')

# Mean error rate by input type
plt.gca().set_ylim(bottom=0, top=17.5) # Hiding negative StD values
sns.barplot(
    ax=axes[1],
    data=df, 
    x='input', 
    y='mean_click_error', 
    ci='sd', 
    capsize=.05, 
    palette='husl'
)
axes[1].set_xlabel('Input Type')
axes[1].set_ylabel('Mean Click Error (%)')

plt.show()
# Out:
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\3640410971.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\3640410971.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\3640410971.py:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\3640410971.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Visualizing the effect of target size on mean completion time and mean click error

# Creating two subfigures
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Mean completion time by input type
sns.barplot(
    ax=axes[0],
    data=df, 
    x='target_size', 
    y='mean_completion_time', 
    ci='sd', 
    capsize=.05, 
    palette='husl'
)
axes[0].set_xlabel('Target Size')
axes[0].set_ylabel('Mean Completion Time (ms)')

# Mean error rate by input type
plt.gca().set_ylim(bottom=0, top=17.5) # Hiding negative StD values
sns.barplot(
    ax=axes[1],
    data=df, 
    x='target_size', 
    y='mean_click_error', 
    ci='sd', 
    capsize=.05, 
    palette='husl'
)
axes[1].set_xlabel('Target Size')
axes[1].set_ylabel('Mean Click Error (%)')

plt.show()
# Out:
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\704857539.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\704857539.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\704857539.py:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# C:\Users\elzha\AppData\Local\Temp\ipykernel_5936\704857539.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Visualization of Input Type and Target Size by the Average Mean Completion Time and the Average Mean Click Error Across all Participants
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

mean_data = df.groupby(['input', 'target_size']).mean_completion_time.mean().unstack()

plt.figure(figsize=(8, 8))
sns.heatmap(mean_data, annot=True, cmap="YlGnBu", fmt=".1f", cbar_kws={'label': 'Mean Completion Time'}, ax=axes[0])
axes[0].set_xlabel('Target Size')
axes[0].set_ylabel('Input Type')

mean_data = df.groupby(['input', 'target_size']).mean_click_error.mean().unstack()
sns.heatmap(mean_data, annot=True, cmap="YlGnBu", fmt=".1f", cbar_kws={'label': 'Mean Click Error'}, ax=axes[1])
axes[1].set_xlabel('Target Size')
axes[1].set_ylabel('Input Type')

plt.show()

# %%
# Visualization of mean completion time by participant and input type
g = sns.catplot(
    data=df, kind="bar",
    x="participant_code", y="mean_completion_time", hue="input",
    errorbar="sd", palette="husl", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Participant Code", "Mean Completion Time")
g.legend.set_title("")

# %%
# Visualization of mean completion time by participant and target_size
g = sns.catplot(
    data=df, kind="bar",
    x="participant_code", y="mean_completion_time", hue="target_size",
    errorbar="sd", palette="husl", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Participant Code", "Mean Completion Time")
g.legend.set_title("")

# %%
g = sns.catplot(
    data=df, kind="bar",
    x="participant_code", y="mean_click_error", hue="input",
    errorbar="sd", palette="husl", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Participant Code", "Mean Click Error")
g.legend.set_title("")

# %% [markdown]
# #### **Two-Way ANOVA/TukeyHSD on Mean Completion Time**

# %%
# Two-way ANOVA for mean completion time
time_model = ols('mean_completion_time ~ C(input) + C(target_size) + C(input):C(target_size)', data=df).fit()
display(sm.stats.anova_lm(time_model, typ=2))
# Out:
#                                sum_sq     df           F        PR(>F)
# C(input)                 3.934636e+06    3.0  112.711293  4.118258e-41
# C(target_size)           2.587749e+06    2.0  111.192673  3.603557e-32
# C(input):C(target_size)  4.315772e+05    6.0    6.181464  6.462320e-06
# Residual                 2.094539e+06  180.0         NaN           NaN

# %%
# TukeyHSD for mean completion time
tukey_input = pairwise_tukeyhsd(endog=df['mean_completion_time'], groups=df['input'], alpha=0.05)
tukey_target = pairwise_tukeyhsd(endog=df['mean_completion_time'], groups=df['target_size'], alpha=0.05)
tukey_input_target = pairwise_tukeyhsd(endog=df['mean_completion_time'], groups=df['input'] + df['target_size'].astype(str), alpha=0.05)
print(tukey_input)
print()
print(tukey_target)
print()
print(tukey_input_target)
# Out:
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================================
#    group1      group2    meandiff p-adj    lower     upper   reject
# -------------------------------------------------------------------
#       Mouse      Stylus -189.8583    0.0 -277.1256 -102.5911   True
#       Mouse Touchscreen -314.8804    0.0 -402.1477 -227.6131   True
#       Mouse    Trackpad   37.3298 0.6846  -49.9375  124.5971  False
#      Stylus Touchscreen -125.0221 0.0015 -212.2894  -37.7548   True
#      Stylus    Trackpad  227.1881    0.0  139.9208  314.4554   True
# Touchscreen    Trackpad  352.2102    0.0  264.9429  439.4775   True
# -------------------------------------------------------------------
#
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
# group1 group2  meandiff p-adj    lower     upper   reject
# ---------------------------------------------------------
#     20     50 -223.7747    0.0  -300.985 -146.5643   True
#     20     80 -263.8545    0.0 -341.0649 -186.6442   True
#     50     80  -40.0798 0.4392 -117.2902   37.1305  False
# ---------------------------------------------------------
#
#           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================
#     group1        group2     meandiff p-adj    lower     upper   reject
# -----------------------------------------------------------------------
#       Mouse20       Mouse50 -332.2175    0.0 -458.5175 -205.9175   True
#       Mouse20       Mouse80   -418.07    0.0   -544.37   -291.77   True
#       Mouse20      Stylus20 -357.9031    0.0 -484.2031 -231.6032   True
#       Mouse20      Stylus50 -494.1738    0.0 -620.4737 -367.8738   True
#       Mouse20      Stylus80 -467.7856    0.0 -594.0856 -341.4857   True
#       Mouse20 Touchscreen20 -432.8838    0.0 -559.1837 -306.5838   True
#       Mouse20 Touchscreen50   -612.55    0.0   -738.85   -486.25   True
#       Mouse20 Touchscreen80  -649.495    0.0  -775.795  -523.195   True
#       Mouse20    Trackpad20  -26.8331 0.9999 -153.1331   99.4668  False
#       Mouse20    Trackpad50 -273.7775    0.0 -400.0775 -147.4775   True
#       Mouse20    Trackpad80 -337.6875    0.0 -463.9875 -211.3875   True
#       Mouse50       Mouse80  -85.8525 0.5152 -212.1525   40.4475  False
#       Mouse50      Stylus20  -25.6856 0.9999 -151.9856  100.6143  False
#       Mouse50      Stylus50 -161.9562  0.002 -288.2562  -35.6563   True
#       Mouse50      Stylus80 -135.5681 0.0237 -261.8681   -9.2682   True
#       Mouse50 Touchscreen20 -100.6662 0.2661 -226.9662   25.6337  False
#       Mouse50 Touchscreen50 -280.3325    0.0 -406.6325 -154.0325   True
#       Mouse50 Touchscreen80 -317.2775    0.0 -443.5775 -190.9775   True
#       Mouse50    Trackpad20  305.3844    0.0  179.0844  431.6843   True
#       Mouse50    Trackpad50     58.44 0.9296    -67.86    184.74  False
#       Mouse50    Trackpad80     -5.47    1.0   -131.77    120.83  False
#       Mouse80      Stylus20   60.1669  0.915  -66.1331  186.4668  False
#       Mouse80      Stylus50  -76.1038 0.6959 -202.4037   50.1962  False
#       Mouse80      Stylus80  -49.7156 0.9778 -176.0156   76.5843  False
#       Mouse80 Touchscreen20  -14.8137    1.0 -141.1137  111.4862  False
#       Mouse80 Touchscreen50   -194.48 0.0001   -320.78    -68.18   True
#       Mouse80 Touchscreen80  -231.425    0.0  -357.725  -105.125   True
#       Mouse80    Trackpad20  391.2369    0.0  264.9369  517.5368   True
#       Mouse80    Trackpad50  144.2925 0.0111   17.9925  270.5925   True
#       Mouse80    Trackpad80   80.3825  0.618  -45.9175  206.6825  False
#      Stylus20      Stylus50 -136.2706 0.0223 -262.5706   -9.9707   True
#      Stylus20      Stylus80 -109.8825 0.1568 -236.1825   16.4175  False
#      Stylus20 Touchscreen20  -74.9806 0.7155 -201.2806   51.3193  False
#      Stylus20 Touchscreen50 -254.6469    0.0 -380.9468 -128.3469   True
#      Stylus20 Touchscreen80 -291.5919    0.0 -417.8918 -165.2919   True
#      Stylus20    Trackpad20    331.07    0.0    204.77    457.37   True
#      Stylus20    Trackpad50   84.1256 0.5477  -42.1743  210.4256  False
#      Stylus20    Trackpad80   20.2156    1.0 -106.0843  146.5156  False
#      Stylus50      Stylus80   26.3881 0.9999  -99.9118  152.6881  False
#      Stylus50 Touchscreen20     61.29 0.9045    -65.01    187.59  False
#      Stylus50 Touchscreen50 -118.3762 0.0895 -244.6762    7.9237  False
#      Stylus50 Touchscreen80 -155.3212 0.0039 -281.6212  -29.0213   True
#      Stylus50    Trackpad20  467.3406    0.0  341.0407  593.6406   True
#      Stylus50    Trackpad50  220.3962    0.0   94.0963  346.6962   True
#      Stylus50    Trackpad80  156.4863 0.0035   30.1863  282.7862   True
#      Stylus80 Touchscreen20   34.9019 0.9989  -91.3981  161.2018  False
#      Stylus80 Touchscreen50 -144.7644 0.0106 -271.0643  -18.4644   True
#      Stylus80 Touchscreen80 -181.7094 0.0002 -308.0093  -55.4094   True
#      Stylus80    Trackpad20  440.9525    0.0  314.6525  567.2525   True
#      Stylus80    Trackpad50  194.0081 0.0001   67.7082  320.3081   True
#      Stylus80    Trackpad80  130.0981 0.0371    3.7982  256.3981   True
# Touchscreen20 Touchscreen50 -179.6663 0.0003 -305.9662  -53.3663   True
# Touchscreen20 Touchscreen80 -216.6113    0.0 -342.9112  -90.3113   True
# Touchscreen20    Trackpad20  406.0506    0.0  279.7507  532.3506   True
# Touchscreen20    Trackpad50  159.1062 0.0027   32.8063  285.4062   True
# Touchscreen20    Trackpad80   95.1962 0.3493  -31.1037  221.4962  False
# Touchscreen50 Touchscreen80   -36.945 0.9982  -163.245    89.355  False
# Touchscreen50    Trackpad20  585.7169    0.0  459.4169  712.0168   True
# Touchscreen50    Trackpad50  338.7725    0.0  212.4725  465.0725   True
# Touchscreen50    Trackpad80  274.8625    0.0  148.5625  401.1625   True
# Touchscreen80    Trackpad20  622.6619    0.0  496.3619  748.9618   True
# Touchscreen80    Trackpad50  375.7175    0.0  249.4175  502.0175   True
# Touchscreen80    Trackpad80  311.8075    0.0  185.5075  438.1075   True
#    Trackpad20    Trackpad50 -246.9444    0.0 -373.2443 -120.6444   True
#    Trackpad20    Trackpad80 -310.8544    0.0 -437.1543 -184.5544   True
#    Trackpad50    Trackpad80    -63.91 0.8769   -190.21     62.39  False
# -----------------------------------------------------------------------

# %% [markdown]
# #### **Two-Way ANOVA/TukeyHSD on Mean Click Error**

# %%
# Two-way ANOVA for mean click error
error_model = ols('mean_click_error ~ C(input) + C(target_size) + C(input):C(target_size)', data=df).fit()
display(sm.stats.anova_lm(error_model, typ=2))
# Out:
#                                sum_sq     df          F        PR(>F)
# C(input)                  2571.238427    3.0  14.883416  1.068471e-08
# C(target_size)            6292.197459    2.0  54.632851  2.869463e-19
# C(input):C(target_size)   6702.210891    6.0  19.397616  2.147902e-17
# Residual                 10365.517506  180.0        NaN           NaN

# %%
# TukeyHSD for mean click error
tukey_hand = pairwise_tukeyhsd(endog=df['mean_click_error'], groups=df['input'], alpha=0.05)
tukey_session = pairwise_tukeyhsd(endog=df['mean_click_error'], groups=df['target_size'], alpha=0.05)
tukey_hand_session = pairwise_tukeyhsd(endog=df['mean_click_error'], groups=df['input'] + df['target_size'].astype(str), alpha=0.05)
print(tukey_hand)
print()
print(tukey_session)
print()
print(tukey_hand_session)
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1      group2   meandiff p-adj   lower    upper  reject
# ---------------------------------------------------------------
#       Mouse      Stylus  -2.6388  0.653  -8.5369  3.2594  False
#       Mouse Touchscreen     6.25 0.0331   0.3519 12.1481   True
#       Mouse    Trackpad  -2.7777 0.6145  -8.6758  3.1204  False
#      Stylus Touchscreen   8.8888 0.0007   2.9906 14.7869   True
#      Stylus    Trackpad   -0.139 0.9999  -6.0371  5.7591  False
# Touchscreen    Trackpad  -9.0277 0.0006 -14.9258 -3.1296   True
# ---------------------------------------------------------------
#
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     20     50 -11.8748    0.0 -16.1317 -7.6179   True
#     20     80 -12.3961    0.0  -16.653 -8.1392   True
#     50     80  -0.5212 0.9549  -4.7781  3.7356  False
# -----------------------------------------------------
#
#         Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================================
#     group1        group2    meandiff p-adj   lower    upper   reject
# --------------------------------------------------------------------
#       Mouse20       Mouse50  -5.8337 0.5703 -14.7187   3.0512  False
#       Mouse20       Mouse80  -5.0012 0.7795 -13.8862   3.8837  False
#       Mouse20      Stylus20  -1.2506    1.0 -10.1356   7.6343  False
#       Mouse20      Stylus50  -7.9169 0.1325 -16.8018   0.9681  False
#       Mouse20      Stylus80  -9.5837 0.0224 -18.4687  -0.6988   True
#       Mouse20 Touchscreen20  24.9994    0.0  16.1144  33.8843   True
#       Mouse20 Touchscreen50  -8.3337 0.0889 -17.2187   0.5512  False
#       Mouse20 Touchscreen80  -8.7506 0.0578 -17.6356   0.1343  False
#       Mouse20    Trackpad20  -5.0006 0.7797 -13.8856   3.8843  False
#       Mouse20    Trackpad50  -6.6669 0.3563 -15.5518   2.2181  False
#       Mouse20    Trackpad80  -7.5006 0.1909 -16.3856   1.3843  False
#       Mouse50       Mouse80   0.8325    1.0  -8.0524   9.7174  False
#       Mouse50      Stylus20   4.5831 0.8623  -4.3018  13.4681  False
#       Mouse50      Stylus50  -2.0831 0.9998 -10.9681   6.8018  False
#       Mouse50      Stylus80    -3.75 0.9627 -12.6349   5.1349  False
#       Mouse50 Touchscreen20  30.8331    0.0  21.9482  39.7181   True
#       Mouse50 Touchscreen50     -2.5 0.9987 -11.3849   6.3849  False
#       Mouse50 Touchscreen80  -2.9169 0.9949 -11.8018   5.9681  False
#       Mouse50    Trackpad20   0.8331    1.0  -8.0518   9.7181  False
#       Mouse50    Trackpad50  -0.8331    1.0  -9.7181   8.0518  False
#       Mouse50    Trackpad80  -1.6669    1.0 -10.5518   7.2181  False
#       Mouse80      Stylus20   3.7506 0.9626  -5.1343  12.6356  False
#       Mouse80      Stylus50  -2.9156 0.9949 -11.8006   5.9693  False
#       Mouse80      Stylus80  -4.5825 0.8624 -13.4674   4.3024  False
#       Mouse80 Touchscreen20  30.0006    0.0  21.1157  38.8856   True
#       Mouse80 Touchscreen50  -3.3325 0.9847 -12.2174   5.5524  False
#       Mouse80 Touchscreen80  -3.7494 0.9627 -12.6343   5.1356  False
#       Mouse80    Trackpad20   0.0006    1.0  -8.8843   8.8856  False
#       Mouse80    Trackpad50  -1.6656    1.0 -10.5506   7.2193  False
#       Mouse80    Trackpad80  -2.4994 0.9987 -11.3843   6.3856  False
#      Stylus20      Stylus50  -6.6662 0.3564 -15.5512   2.2187  False
#      Stylus20      Stylus80  -8.3331  0.089 -17.2181   0.5518  False
#      Stylus20 Touchscreen20    26.25    0.0  17.3651  35.1349   True
#      Stylus20 Touchscreen50  -7.0831 0.2658 -15.9681   1.8018  False
#      Stylus20 Touchscreen80     -7.5  0.191 -16.3849   1.3849  False
#      Stylus20    Trackpad20    -3.75 0.9627 -12.6349   5.1349  False
#      Stylus20    Trackpad50  -5.4163 0.6801 -14.3012   3.4687  False
#      Stylus20    Trackpad80    -6.25 0.4598 -15.1349   2.6349  False
#      Stylus50      Stylus80  -1.6669    1.0 -10.5518   7.2181  False
#      Stylus50 Touchscreen20  32.9163    0.0  24.0313  41.8012   True
#      Stylus50 Touchscreen50  -0.4169    1.0  -9.3018   8.4681  False
#      Stylus50 Touchscreen80  -0.8338    1.0  -9.7187   8.0512  False
#      Stylus50    Trackpad20   2.9162 0.9949  -5.9687  11.8012  False
#      Stylus50    Trackpad50     1.25    1.0  -7.6349  10.1349  False
#      Stylus50    Trackpad80   0.4162    1.0  -8.4687   9.3012  False
#      Stylus80 Touchscreen20  34.5831    0.0  25.6982  43.4681   True
#      Stylus80 Touchscreen50     1.25    1.0  -7.6349  10.1349  False
#      Stylus80 Touchscreen80   0.8331    1.0  -8.0518   9.7181  False
#      Stylus80    Trackpad20   4.5831 0.8623  -4.3018  13.4681  False
#      Stylus80    Trackpad50   2.9169 0.9949  -5.9681  11.8018  False
#      Stylus80    Trackpad80   2.0831 0.9998  -6.8018  10.9681  False
# Touchscreen20 Touchscreen50 -33.3331    0.0 -42.2181 -24.4482   True
# Touchscreen20 Touchscreen80   -33.75    0.0 -42.6349 -24.8651   True
# Touchscreen20    Trackpad20    -30.0    0.0 -38.8849 -21.1151   True
# Touchscreen20    Trackpad50 -31.6663    0.0 -40.5512 -22.7813   True
# Touchscreen20    Trackpad80    -32.5    0.0 -41.3849 -23.6151   True
# Touchscreen50 Touchscreen80  -0.4169    1.0  -9.3018   8.4681  False
# Touchscreen50    Trackpad20   3.3331 0.9847  -5.5518  12.2181  False
# Touchscreen50    Trackpad50   1.6669    1.0  -7.2181  10.5518  False
# Touchscreen50    Trackpad80   0.8331    1.0  -8.0518   9.7181  False
# Touchscreen80    Trackpad20     3.75 0.9627  -5.1349  12.6349  False
# Touchscreen80    Trackpad50   2.0838 0.9998  -6.8012  10.9687  False
# Touchscreen80    Trackpad80     1.25    1.0  -7.6349  10.1349  False
#    Trackpad20    Trackpad50  -1.6662    1.0 -10.5512   7.2187  False
#    Trackpad20    Trackpad80     -2.5 0.9987 -11.3849   6.3849  False
#    Trackpad50    Trackpad80  -0.8338    1.0  -9.7187   8.0512  False
# --------------------------------------------------------------------
